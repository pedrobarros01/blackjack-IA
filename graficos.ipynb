# %%
import seaborn as sns
import pandas as pd

# %%
df_random = pd.read_csv('grafico_aleatorio.txt', sep='-')
df_random
# Out:
#    iter    winrate
# 0   100  28.000000
# 1   200  26.000000
# 2   300  25.333333
# 3   400  24.750000
# 4   500  25.400000

# %%
df_pol1_qlearning = pd.read_csv('grafico_q_learning_pol1.txt', sep='-')
df_pol1_qlearning
# Out:
#    iter  winrate
# 0   100     25.0
# 1   200     28.0
# 2   300     29.0
# 3   400     28.0
# 4   500     28.0

# %%
df_pol2_qlearning = pd.read_csv('grafico_q_learning_pol2.txt', sep='-')
df_pol2_qlearning
# Out:
#    iter    winrate
# 0   100  30.000000
# 1   200  32.500000
# 2   300  36.333333
# 3   400  37.500000
# 4   500  38.200000

# %%
df_pol1_sarsa = pd.read_csv('grafico_sarsa_pol1.txt', sep='-')
df_pol1_sarsa
# Out:
#    iter    winrate
# 0   100  28.000000
# 1   200  26.500000
# 2   300  25.666667
# 3   400  26.000000
# 4   500  25.800000

# %%
df_pol2_sarsa = pd.read_csv('grafico_sarsa_pol2.txt', sep='-')
df_pol2_sarsa
# Out:
#    iter    winrate
# 0   100  43.000000
# 1   200  39.000000
# 2   300  37.666667
# 3   400  40.000000
# 4   500  40.800000

# %%
df_random['iter'] = df_random['iter'].astype('int')
df_random['winrate'] =df_random['winrate'].astype('float')

df_pol1_qlearning['iter'] = df_pol1_qlearning['iter'].astype('int')
df_pol1_qlearning['winrate'] =df_pol1_qlearning['winrate'].astype('float')

df_pol2_qlearning['iter'] = df_pol2_qlearning['iter'].astype('int')
df_pol2_qlearning['winrate'] =df_pol2_qlearning['winrate'].astype('float')

df_pol1_sarsa['iter'] = df_pol1_sarsa['iter'].astype('int')
df_pol1_sarsa['winrate'] =df_pol1_sarsa['winrate'].astype('float')

df_pol2_sarsa['iter'] = df_pol2_sarsa['iter'].astype('int')
df_pol2_sarsa['winrate'] =df_pol2_sarsa['winrate'].astype('float')

# %%
df_pol1_sarsa['policy'] = 'pol1-sarsa'
df_pol2_sarsa['policy'] = 'pol2-sarsa'
df_random['policy'] = 'random'
df_pol2_qlearning['policy'] = 'pol2-qlearning'
df_pol1_qlearning['policy'] = 'pol1-qlearning'

# %%
df_total = pd.concat([df_random, df_pol1_qlearning, df_pol2_qlearning, df_pol1_sarsa, df_pol2_sarsa])
df_total
# Out:
#    iter    winrate          policy
# 0   100  28.000000          random
# 1   200  26.000000          random
# 2   300  25.333333          random
# 3   400  24.750000          random
# 4   500  25.400000          random
# 0   100  25.000000  pol1-qlearning
# 1   200  28.000000  pol1-qlearning
# 2   300  29.000000  pol1-qlearning
# 3   400  28.000000  pol1-qlearning
# 4   500  28.000000  pol1-qlearning
# 0   100  30.000000  pol2-qlearning
# 1   200  32.500000  pol2-qlearning
# 2   300  36.333333  pol2-qlearning
# 3   400  37.500000  pol2-qlearning
# 4   500  38.200000  pol2-qlearning
# 0   100  28.000000      pol1-sarsa
# 1   200  26.500000      pol1-sarsa
# 2   300  25.666667      pol1-sarsa
# 3   400  26.000000      pol1-sarsa
# 4   500  25.800000      pol1-sarsa
# 0   100  43.000000      pol2-sarsa
# 1   200  39.000000      pol2-sarsa
# 2   300  37.666667      pol2-sarsa
# 3   400  40.000000      pol2-sarsa
# 4   500  40.800000      pol2-sarsa

# %%
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(x="iter", y="winrate",
             hue="policy",
             data=df_total)
# Out:
# <Axes: xlabel='iter', ylabel='winrate'>
